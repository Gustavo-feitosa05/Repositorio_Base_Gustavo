# %% [markdown]
# ### PYAUTOGUI

# %%
import pyautogui as aut

aut.mouseInfo()

# %%
import pyautogui as aut

aut.press("Win") # Press = Clicar
aut.sleep(1) # Sleep = Pausa
aut.write("bloco de notas") # Write = Escrever
aut.press("Enter") # Press = Clicar
aut.sleep(1)
aut.write("Ola mundo! Que dia bom :-)", interval= 0.5)

# %% [markdown]
# ### CALCULADORA FODA

# %%
# ----- CALCULADORA FODA ----- #

import pyautogui as aut

aut.press("Win")
aut.sleep(1)
aut.write("Calculadora")
aut.press("Enter")
aut.sleep(1)
aut.press("5")
aut.sleep(0.5)
aut.press("0")
aut.sleep(0.5)
aut.press("+")
aut.sleep(0.5)
aut.press("5")
aut.sleep(0.5)
aut.press("0")
aut.sleep(0.5)
aut.press("=")
aut.sleep(3)
aut.moveTo(344,46)
aut.click()

# %% [markdown]
# ### MAPAS SANTANA

# %%
import pyautogui as aut

aut.press("Win")
aut.sleep(1)
aut.write("Mapas")
aut.press("Enter")
aut.sleep(1)
aut.write("Santana de Parna", interval= 0.3)
aut.moveTo(226,217)
aut.sleep(1)
aut.click()

# %% [markdown]
# ### CÒDIGO.PNG.FODA

# %%
import pyautogui as aut

nome = ""
aut.moveTo(143,474)
aut.sleep(1)
aut.click()
aut.sleep(1)
aut.moveTo(434,155)
aut.sleep(1)
aut.click()
aut.sleep(1)
aut.write("nome = input('qual o seu nome')", interval= 0.2)
aut.sleep(1)
aut.press("Enter")
aut.sleep(1)
aut.write(f"print(nome)", interval= 0.2)
aut.sleep(1)
aut.moveTo(367,145)
aut.sleep(1)
aut.click()
aut.write("Gustavo", interval= 0.2)
aut.press("Enter")

# %% [markdown]
# ### CÒDIGOS PARA PREGUIÇOSOS

# %%
import pyautogui as aut

nome = ""
aut.moveTo(143,474) #Mover para algum lugar
aut.sleep(0.5) #Pausa
aut.click() #Clicar
aut.sleep(0.5) #Pausa
aut.moveTo(434,155)
aut.sleep(0.5) #Pausa
aut.click() #Clicar
aut.sleep(0.5) #Pausa
aut.write("idade = int(input('Digite a sua idade'))", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("if idade < 18:", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("print('menor de idade')", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("elif idade == 18:", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("print('maior de idade')", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("elif idade >= 19 or idade < 60:", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("print('Adulto')", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla
aut.press("Enter") #Apertar uma tecla
aut.sleep(0.5) #Pausa
aut.write("elif idade >= 60:", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("print('Velho')", interval=0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.moveTo(367,145)
aut.sleep(0.5) #Pausa
aut.click() #Clicar
aut.sleep(0.5) #Pausa
aut.write("19", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla

# %% [markdown]
# ### TRANSCENDENCIA DO PYAUTOGUI

# %%
import pyautogui as aut

aut.moveTo(143,474) #Mover para algum lugar
aut.sleep(0.5) #Pausa
aut.click() #Clicar
aut.sleep(0.5) #Pausa
aut.moveTo(434,155)
aut.sleep(0.5) #Pausa
aut.click() #Clicar
aut.sleep(0.5) #Pausa
aut.write("import pyautogui as aut", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.press('Win')", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.sleep(1)", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.write('bloco de notas')", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.press('Enter')", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.sleep(1)", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.press("Enter") #Apertar uma tecla 
aut.sleep(0.5) #Pausa
aut.write("aut.write('Ola mundo! Que dia bom :-)', interval= 0.2)", interval= 0.2) #Escrever algo
aut.sleep(0.5) #Pausa
aut.moveTo(367,145) #Mover para algum lugar
aut.sleep(0.5) #Pausa
aut.click() #Clicar

# %%
import pyautogui as aut
email = "gustavofeitosa0205@gmail.com"
assunto = "Fazer programa"

aut.press("Win")
aut.sleep(1) #Pausa
aut.write("g")
aut.sleep(1) #Pausa
aut.press("Enter")
aut.sleep(1) #Pausa
aut.moveTo(922,623) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(1720,167) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(76,234) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(1423,1001) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(89,296) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(286,186) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(786,503) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(1329,474) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.write(email)
aut.sleep(1) #Pausa
aut.moveTo(1788,521) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.write(assunto)
aut.sleep(1) #Pausa
aut.moveTo(1306,1002) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar

# %%
import pyautogui as aut

aut.mouseInfo()

# %%
import pyautogui as aut
1911,645
aut.press("Win")
aut.sleep(1) #Pausa
aut.write("ch")
aut.sleep(1) #Pausa
aut.press("Enter")
aut.sleep(1) #Pausa
aut.moveTo(922,623) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(729,423) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.write("senai santana de parnaiba", interval= 0.1)
aut.sleep(1) #Pausa
aut.press("Enter")
aut.sleep(1) #Pausa
aut.moveTo(320,411) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(1254,522) #Mover para algum lugar
aut.sleep(1) #Pausa
aut.click() #Clicar
aut.sleep(1) #Pausa
aut.moveTo(442,374) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.click() #Clicar
aut.sleep(2) #Pausa
aut.write("Python", interval= 0.1)
aut.sleep(2) #Pausa
aut.moveTo(438,466) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.click() #Clicar
aut.sleep(2) #Pausa
aut.moveTo(550,380) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.moveTo(1260,711) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.click() #Clicar
aut.sleep(2) #Pausa
aut.moveTo(1914,678) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.doubleClick() #Clicar
aut.sleep(2) #Pausa
aut.moveTo(1264,879) #Mover para algum lugar
aut.sleep(2) #Pausa
aut.click() #Clicar
