# %% [markdown]
# ### 📝Lista de Exercícios: Condicionais IF/ELSE

# %% [markdown]
# Exercício 1 - Maioridade 🔞
#
# Crie um programa que pergunta a idade do usuário e diz se ele é maior ou menor de idade.

# %%
idade = int(input("Quantos anos você tem? "))

# Complete o código aqui

if idade >= 18:
    print("Vc é maior de idade!")

elif idade < 18:
    print("Vc é menor de idade!")
# Out:
# Vc é menor de idade!

# %% [markdown]
# Exercício 2 - Aprovação na Prova 🧠
#
# Faça um programa que pergunte a nota de um aluno (0 a 10) e diz se ele foi aprovado(nota >= 5) ou reprovado (nota <5).

# %%
nota = float(input("Informe a sua nota de (0 a 10)"))

# Complete o código aqui

if nota >= 5:
    print("Vc foi aprovado!")

elif nota < 5:
    print("Vc foi reprovado!")
# Out:
# Vc foi reprovado!

# %% [markdown]
# Exercicio 3 - CNH 🚘🚙
#
#  1º - Peça ao usuário que digite a idade dele.
#
#  2º - Peça pra ele dizer se foi aprovado ou reprovado no curso de cnh.
#
#  3º - Use if e else para verificar se ele tem 18 anos ou mais e se foi aprovado.
#
#  4º - Se as condições do passo 3 estiverem certas, print("pode dirigir").
#
#  5º - Se não print("vai andar a pé")

# %%
### Seu código aqui
idade = int(input("Informe a sua idade"))
aprovacao_cnh = input("A sua cnh foi aprovada? (sim/não)")

if idade >= 18 and aprovacao_cnh == "sim":
    print("Pode dirigir")

else:
    print("Vai andar a pé")
# Out:
# Vai andar a pé

# %% [markdown]
# Exercício 4 - Calculadora de Desconto. 💵 🤑
#
# Uma loja dá 10% de desconto para compras acima de R$ 100,00. Faça um programa que:
#
# 1º - Pergunta o valor da compra.
#
# 2º - Calcula o valor final com desconto (se aplicável).
#
# 3º - Mostra o valor a pagar.

# %%
### Seu código aqui

valor = float(input("Qual foi o valor da compra??"))

if valor >= 100:
    desconto = valor * 0.10
    total = valor - desconto
    print(f"Vc teve um desconto de 10%! Sua compra saiu por: {total}")

else:
    print(f"A sua compra saiu por {valor}")
# Out:
# Vc teve um desconto de 10%! Sua compra saiu por: 270.0

# %% [markdown]
# Exercício 5 - Classificação de Notas 🧑‍🎓
#
# Pergunte a nota de um aluno e dependendo da nota que ele informar, o classifique de acordo com as regras abaixo:
#
# Classifique a nota do aluno:
#
# - 9 até 10: "Excelente"
#
# - 7 até 8.9: "Bom"
#
# - 5 até 6.9: "Regular"
#
# - 0 até 4.9: "Reprovado"
#
# mostre para o aluno a classificação dele através de um print, exemplo print("Excelente").

# %%
nota = float(input("Qual a sua nota ? :"))

if nota >= 9.0 and nota <= 10:
    print("Excelente")

elif nota >= 7.0 and nota <= 8.9:
    print("Bom")

elif nota >= 5.0 and nota <= 6.9:
    print("Bom")

else:
    print("Reprovado")
# Out:
# Reprovado

# %% [markdown]
# Exercício 6 - Acesso ao Sistema 🔑
#
# Crie um login simples:
#
# - usuario_correto = "admin"
#
# - senha_correta = "1234"
#
# **Peça para o usuário digitar primeiro o login e depois a senha, caso login e senha estejam corretos programa deve mostrar "Acesso permitido" se não "Acesso negado"**

# %%
usuario_correto = input("Qual é o seu usuario???")
senha_correta = int(input("Qual a sua senha???"))

if usuario_correto == "admin" and senha_correta == 1234:
    print("Acesso permitido")

else:
    print("Acesso negado")
# Out:
# Acesso permitido

# %% [markdown]
# Exercício 7 - Maior Número 📉
#
# Peça 3 números e mostre qual é o maior deles.

# %%
print("Digite trés números")

numero_1 = int(input("Digite o seu primeiro número"))
numero_2 = int(input("Digite o seu segundo número"))
numero_3 = int(input("Digite o seu terceiro número"))

maior = max(numero_1, numero_2, numero_3)

print(f"O maior número é {maior}")
# Out:
# Digite trés números
# O maior número é 13

# %% [markdown]
# Exercício 8 - Dia da Semana
# Peça um número de 1 a 7 e mostre o dia da semana correspondente: 📅
#
# - 1: Domingo
#
# - 2: Segunda
#
# - ... até 7: Sábado

# %%
numero = int(input("Digite um número de 1 até 7"))

if numero == 1:
    print("Domingo")

elif numero == 2:
    print("Segunda")

elif numero == 3:
    print("Terça")

elif numero == 4:
    print("Quarta")

elif numero == 5:
    print("Quinta")

elif numero == 6:
    print("Sexta")

elif numero == 7:
    print("Sábado")
# Out:
# Quinta

# %% [markdown]
# Exercício 9 - Calculadora Simples 📏📐
#
# - Faça uma calculadora que:
#
# - Pede dois números
#
# - Pede a operação (+, -, *, /)
#
# - Dependendo da operação mostre o resultado.

# %%
numero_1 = float(input("Informe um número"))
operaçao = (input("Digite uma operação"))
numero_2 = float(input("Informe um segundo número"))

if operaçao == "adição" or operaçao == "+":
    soma = numero_1 + numero_2
    print(soma)

if operaçao == "subtração" or operaçao == "-":
    subtraçao = numero_1 - numero_2
    print(subtraçao)

if operaçao == "multiplicação" or operaçao == "*":
    multiplicação = numero_1 * numero_2
    print(multiplicação)

if operaçao == "divisão" or operaçao == "/":
    divisão = numero_1 / numero_2
    print(divisão)
# Out:
# 40.0

# %% [markdown]
# Exercício 10 - Sistema de Multas 🚙🚘🧾
#
#
# - Velocidade máxima: 80 km/h 🚫
#
# - Até 80: "Sem multa"
#
# - 81-100: "Multa leve"
#
# - Acima de 100: "Multa grave"

# %%
velocidade = int(input("Informe a velocidade"))

if velocidade <= 80:
    print("Sem multa")

elif velocidade >= 81 and velocidade <= 100:
    print("Multa leve")

elif velocidade > 100:
    print("Multa grave")
# Out:
# Multa leve
